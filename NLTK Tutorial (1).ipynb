# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/avinash/anaconda3/lib/python3.9/site-packages (3.6.5)
# Requirement already satisfied: click in /home/avinash/anaconda3/lib/python3.9/site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in /home/avinash/anaconda3/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/avinash/anaconda3/lib/python3.9/site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in /home/avinash/anaconda3/lib/python3.9/site-packages (from nltk) (4.62.3)

# %%
text = """Sri Lanka defeated Pakistan by 23 runs in the summit clash of Asia Cup 2022, on Sunday at Dubai International Stadium. The unbeaten knock of 71 runs by Bhanuka Rajapaksa and a four-wicket haul by Pramod Madushan, helped Sri Lanka clinch their sixth Asia Cup title. The team has been garnering praise from all over the world for their spectacular performance in the tournament and following their win, the players took part in a massive victory parade, when they returned home on Tuesday morning. The players were welcomed by officials from Sri Lanka Cricket and the Sports Ministry at the Bandaranaike International Airport.

In the pictures posted by Sri Lanka Cricket on their Twitter, the players were seen travelling in a double-decker bus, with fans on the roadside cheering and congratulating them. The players also interacted with the fans and thanked them for their massive support, even during the time of crisis in the country.

men's
"""

# %%
print(text)
# Out:
# Sri Lanka defeated Pakistan by 23 runs in the summit clash of Asia Cup 2022, on Sunday at Dubai International Stadium. The unbeaten knock of 71 runs by Bhanuka Rajapaksa and a four-wicket haul by Pramod Madushan, helped Sri Lanka clinch their sixth Asia Cup title. The team has been garnering praise from all over the world for their spectacular performance in the tournament and following their win, the players took part in a massive victory parade, when they returned home on Tuesday morning. The players were welcomed by officials from Sri Lanka Cricket and the Sports Ministry at the Bandaranaike International Airport.
#
# In the pictures posted by Sri Lanka Cricket on their Twitter, the players were seen travelling in a double-decker bus, with fans on the roadside cheering and congratulating them. The players also interacted with the fans and thanked them for their massive support, even during the time of crisis in the country.
#
# men's

# %% [markdown]
# ## Text Normalization

# %%
text = text.lower()

# %% [markdown]
# # Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize

sent_tokenize(text)
# Out:
# ['sri lanka defeated pakistan by 23 runs in the summit clash of asia cup 2022, on sunday at dubai international stadium.',
#  'the unbeaten knock of 71 runs by bhanuka rajapaksa and a four-wicket haul by pramod madushan, helped sri lanka clinch their sixth asia cup title.',
#  'the team has been garnering praise from all over the world for their spectacular performance in the tournament and following their win, the players took part in a massive victory parade, when they returned home on tuesday morning.',
#  'the players were welcomed by officials from sri lanka cricket and the sports ministry at the bandaranaike international airport.',
#  'in the pictures posted by sri lanka cricket on their twitter, the players were seen travelling in a double-decker bus, with fans on the roadside cheering and congratulating them.',
#  'the players also interacted with the fans and thanked them for their massive support, even during the time of crisis in the country.',
#  "men's"]

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/avinash/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Word Tokenization

# %%
from nltk.tokenize import word_tokenize

tokenized_words = word_tokenize(text)

print(tokenized_words)
# Out:
# ['sri', 'lanka', 'defeated', 'pakistan', 'by', '23', 'runs', 'in', 'the', 'summit', 'clash', 'of', 'asia', 'cup', '2022', ',', 'on', 'sunday', 'at', 'dubai', 'international', 'stadium', '.', 'the', 'unbeaten', 'knock', 'of', '71', 'runs', 'by', 'bhanuka', 'rajapaksa', 'and', 'a', 'four-wicket', 'haul', 'by', 'pramod', 'madushan', ',', 'helped', 'sri', 'lanka', 'clinch', 'their', 'sixth', 'asia', 'cup', 'title', '.', 'the', 'team', 'has', 'been', 'garnering', 'praise', 'from', 'all', 'over', 'the', 'world', 'for', 'their', 'spectacular', 'performance', 'in', 'the', 'tournament', 'and', 'following', 'their', 'win', ',', 'the', 'players', 'took', 'part', 'in', 'a', 'massive', 'victory', 'parade', ',', 'when', 'they', 'returned', 'home', 'on', 'tuesday', 'morning', '.', 'the', 'players', 'were', 'welcomed', 'by', 'officials', 'from', 'sri', 'lanka', 'cricket', 'and', 'the', 'sports', 'ministry', 'at', 'the', 'bandaranaike', 'international', 'airport', '.', 'in', 'the', 'pictures', 'posted', 'by', 'sri', 'lanka', 'cricket', 'on', 'their', 'twitter', ',', 'the', 'players', 'were', 'seen', 'travelling', 'in', 'a', 'double-decker', 'bus', ',', 'with', 'fans', 'on', 'the', 'roadside', 'cheering', 'and', 'congratulating', 'them', '.', 'the', 'players', 'also', 'interacted', 'with', 'the', 'fans', 'and', 'thanked', 'them', 'for', 'their', 'massive', 'support', ',', 'even', 'during', 'the', 'time', 'of', 'crisis', 'in', 'the', 'country', '.', 'men', "'s"]

# %%
from nltk.probability import FreqDist

fd = FreqDist(tokenized_words)

fd.most_common(5)
# Out:
# [('the', 16), (',', 7), ('in', 6), ('.', 6), ('by', 5)]

# %%
fd.plot(30,cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt

fd.plot(30,cumulative=False)
plt.show()

# %% [markdown]
# # Remove Stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/avinash/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

stop_words=stopwords.words("english")

print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
import string

punctuations = list(string.punctuation)

print(punctuations)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %%
other_stop_words = ["'s", ]

# %%
filtered_tokens = []

for word in tokenized_words:
    if word not in stop_words + punctuations + other_stop_words:
        filtered_tokens.append(word)

# %%
print(filtered_tokens)
# Out:
# ['sri', 'lanka', 'defeated', 'pakistan', '23', 'runs', 'summit', 'clash', 'asia', 'cup', '2022', 'sunday', 'dubai', 'international', 'stadium', 'unbeaten', 'knock', '71', 'runs', 'bhanuka', 'rajapaksa', 'four-wicket', 'haul', 'pramod', 'madushan', 'helped', 'sri', 'lanka', 'clinch', 'sixth', 'asia', 'cup', 'title', 'team', 'garnering', 'praise', 'world', 'spectacular', 'performance', 'tournament', 'following', 'win', 'players', 'took', 'part', 'massive', 'victory', 'parade', 'returned', 'home', 'tuesday', 'morning', 'players', 'welcomed', 'officials', 'sri', 'lanka', 'cricket', 'sports', 'ministry', 'bandaranaike', 'international', 'airport', 'pictures', 'posted', 'sri', 'lanka', 'cricket', 'twitter', 'players', 'seen', 'travelling', 'double-decker', 'bus', 'fans', 'roadside', 'cheering', 'congratulating', 'players', 'also', 'interacted', 'fans', 'thanked', 'massive', 'support', 'even', 'time', 'crisis', 'country', 'men']

# %%
from nltk.probability import FreqDist

fd = FreqDist(filtered_tokens)

fd.most_common(5)
# Out:
# [('sri', 4), ('lanka', 4), ('players', 4), ('runs', 2), ('asia', 2)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt

fd.plot(30,cumulative=False)
plt.show()

# %%
# Stemming
from nltk.stem import PorterStemmer

ps = PorterStemmer()

stemmed_words=[]

for w in filtered_tokens:     
     stemmed_words.append(ps.stem(w))

print("Filtered Tokens After Removing Punctuations:",filtered_tokens)
print("Stemmed Tokens:",stemmed_words)
# Out:
# Filtered Tokens After Removing Punctuations: ['sri', 'lanka', 'defeated', 'pakistan', '23', 'runs', 'summit', 'clash', 'asia', 'cup', '2022', 'sunday', 'dubai', 'international', 'stadium', 'unbeaten', 'knock', '71', 'runs', 'bhanuka', 'rajapaksa', 'four-wicket', 'haul', 'pramod', 'madushan', 'helped', 'sri', 'lanka', 'clinch', 'sixth', 'asia', 'cup', 'title', 'team', 'garnering', 'praise', 'world', 'spectacular', 'performance', 'tournament', 'following', 'win', 'players', 'took', 'part', 'massive', 'victory', 'parade', 'returned', 'home', 'tuesday', 'morning', 'players', 'welcomed', 'officials', 'sri', 'lanka', 'cricket', 'sports', 'ministry', 'bandaranaike', 'international', 'airport', 'pictures', 'posted', 'sri', 'lanka', 'cricket', 'twitter', 'players', 'seen', 'travelling', 'double-decker', 'bus', 'fans', 'roadside', 'cheering', 'congratulating', 'players', 'also', 'interacted', 'fans', 'thanked', 'massive', 'support', 'even', 'time', 'crisis', 'country', 'men']
# Stemmed Tokens: ['sri', 'lanka', 'defeat', 'pakistan', '23', 'run', 'summit', 'clash', 'asia', 'cup', '2022', 'sunday', 'dubai', 'intern', 'stadium', 'unbeaten', 'knock', '71', 'run', 'bhanuka', 'rajapaksa', 'four-wicket', 'haul', 'pramod', 'madushan', 'help', 'sri', 'lanka', 'clinch', 'sixth', 'asia', 'cup', 'titl', 'team', 'garner', 'prais', 'world', 'spectacular', 'perform', 'tournament', 'follow', 'win', 'player', 'took', 'part', 'massiv', 'victori', 'parad', 'return', 'home', 'tuesday', 'morn', 'player', 'welcom', 'offici', 'sri', 'lanka', 'cricket', 'sport', 'ministri', 'bandaranaik', 'intern', 'airport', 'pictur', 'post', 'sri', 'lanka', 'cricket', 'twitter', 'player', 'seen', 'travel', 'double-deck', 'bu', 'fan', 'roadsid', 'cheer', 'congratul', 'player', 'also', 'interact', 'fan', 'thank', 'massiv', 'support', 'even', 'time', 'crisi', 'countri', 'men']

# %%
from nltk.stem.lancaster import LancasterStemmer

st = LancasterStemmer()

stemmed_words=[]

for w in filtered_tokens:     
     stemmed_words.append(st.stem(w))

print("Filtered Tokens After Removing Punctuations:",filtered_tokens)
print("Stemmed Tokens:",stemmed_words)
# Out:
# Filtered Tokens After Removing Punctuations: ['sri', 'lanka', 'defeated', 'pakistan', '23', 'runs', 'summit', 'clash', 'asia', 'cup', '2022', 'sunday', 'dubai', 'international', 'stadium', 'unbeaten', 'knock', '71', 'runs', 'bhanuka', 'rajapaksa', 'four-wicket', 'haul', 'pramod', 'madushan', 'helped', 'sri', 'lanka', 'clinch', 'sixth', 'asia', 'cup', 'title', 'team', 'garnering', 'praise', 'world', 'spectacular', 'performance', 'tournament', 'following', 'win', 'players', 'took', 'part', 'massive', 'victory', 'parade', 'returned', 'home', 'tuesday', 'morning', 'players', 'welcomed', 'officials', 'sri', 'lanka', 'cricket', 'sports', 'ministry', 'bandaranaike', 'international', 'airport', 'pictures', 'posted', 'sri', 'lanka', 'cricket', 'twitter', 'players', 'seen', 'travelling', 'double-decker', 'bus', 'fans', 'roadside', 'cheering', 'congratulating', 'players', 'also', 'interacted', 'fans', 'thanked', 'massive', 'support', 'even', 'time', 'crisis', 'country', 'men']
# Stemmed Tokens: ['sri', 'lank', 'def', 'pak', '23', 'run', 'summit', 'clash', 'as', 'cup', '2022', 'sunday', 'duba', 'intern', 'stad', 'unb', 'knock', '71', 'run', 'bhanuk', 'rajapaks', 'four-wicket', 'haul', 'pramod', 'madush', 'help', 'sri', 'lank', 'clinch', 'six', 'as', 'cup', 'titl', 'team', 'garn', 'pra', 'world', 'spectacul', 'perform', 'tourna', 'follow', 'win', 'play', 'took', 'part', 'mass', 'vict', 'parad', 'return', 'hom', 'tuesday', 'morn', 'play', 'welcom', 'off', 'sri', 'lank', 'cricket', 'sport', 'min', 'bandaranaik', 'intern', 'airport', 'pict', 'post', 'sri', 'lank', 'cricket', 'twit', 'play', 'seen', 'travel', 'double-decker', 'bus', 'fan', 'roadsid', 'che', 'congrat', 'play', 'also', 'interact', 'fan', 'thank', 'mass', 'support', 'ev', 'tim', 'cris', 'country', 'men']

# %%
from nltk.stem import SnowballStemmer

sb = SnowballStemmer("english") # Choose a language

for w in filtered_tokens:     
     stemmed_words.append(sb.stem(w))

print("Filtered Tokens After Removing Punctuations:",filtered_tokens)
print("Stemmed Tokens:",stemmed_words)
# Out:
# Filtered Tokens After Removing Punctuations: ['sri', 'lanka', 'defeated', 'pakistan', '23', 'runs', 'summit', 'clash', 'asia', 'cup', '2022', 'sunday', 'dubai', 'international', 'stadium', 'unbeaten', 'knock', '71', 'runs', 'bhanuka', 'rajapaksa', 'four-wicket', 'haul', 'pramod', 'madushan', 'helped', 'sri', 'lanka', 'clinch', 'sixth', 'asia', 'cup', 'title', 'team', 'garnering', 'praise', 'world', 'spectacular', 'performance', 'tournament', 'following', 'win', 'players', 'took', 'part', 'massive', 'victory', 'parade', 'returned', 'home', 'tuesday', 'morning', 'players', 'welcomed', 'officials', 'sri', 'lanka', 'cricket', 'sports', 'ministry', 'bandaranaike', 'international', 'airport', 'pictures', 'posted', 'sri', 'lanka', 'cricket', 'twitter', 'players', 'seen', 'travelling', 'double-decker', 'bus', 'fans', 'roadside', 'cheering', 'congratulating', 'players', 'also', 'interacted', 'fans', 'thanked', 'massive', 'support', 'even', 'time', 'crisis', 'country', 'men']
# Stemmed Tokens: ['sri', 'lank', 'def', 'pak', '23', 'run', 'summit', 'clash', 'as', 'cup', '2022', 'sunday', 'duba', 'intern', 'stad', 'unb', 'knock', '71', 'run', 'bhanuk', 'rajapaks', 'four-wicket', 'haul', 'pramod', 'madush', 'help', 'sri', 'lank', 'clinch', 'six', 'as', 'cup', 'titl', 'team', 'garn', 'pra', 'world', 'spectacul', 'perform', 'tourna', 'follow', 'win', 'play', 'took', 'part', 'mass', 'vict', 'parad', 'return', 'hom', 'tuesday', 'morn', 'play', 'welcom', 'off', 'sri', 'lank', 'cricket', 'sport', 'min', 'bandaranaik', 'intern', 'airport', 'pict', 'post', 'sri', 'lank', 'cricket', 'twit', 'play', 'seen', 'travel', 'double-decker', 'bus', 'fan', 'roadsid', 'che', 'congrat', 'play', 'also', 'interact', 'fan', 'thank', 'mass', 'support', 'ev', 'tim', 'cris', 'country', 'men', 'sri', 'lanka', 'defeat', 'pakistan', '23', 'run', 'summit', 'clash', 'asia', 'cup', '2022', 'sunday', 'dubai', 'intern', 'stadium', 'unbeaten', 'knock', '71', 'run', 'bhanuka', 'rajapaksa', 'four-wicket', 'haul', 'pramod', 'madushan', 'help', 'sri', 'lanka', 'clinch', 'sixth', 'asia', 'cup', 'titl', 'team', 'garner', 'prais', 'world', 'spectacular', 'perform', 'tournament', 'follow', 'win', 'player', 'took', 'part', 'massiv', 'victori', 'parad', 'return', 'home', 'tuesday', 'morn', 'player', 'welcom', 'offici', 'sri', 'lanka', 'cricket', 'sport', 'ministri', 'bandaranaik', 'intern', 'airport', 'pictur', 'post', 'sri', 'lanka', 'cricket', 'twitter', 'player', 'seen', 'travel', 'double-deck', 'bus', 'fan', 'roadsid', 'cheer', 'congratul', 'player', 'also', 'interact', 'fan', 'thank', 'massiv', 'support', 'even', 'time', 'crisi', 'countri', 'men']

# %% [markdown]
# ## Lemmatization

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/avinash/nltk_data...
# True

# %%
#Lexicon Normalization#performing stemming and Lemmatization
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

lem = WordNetLemmatizer()
stem = PorterStemmer()
word = "flying"

print("Lemmatized Word:",lem.lemmatize(word,"v"))

print("Stemmed Word:",stem.stem(word))
# Out:
# Lemmatized Word: fly
# Stemmed Word: fli

# %%
lem = WordNetLemmatizer()

lemmetized_words = []

for w in filtered_tokens:     
     lemmetized_words.append(lem.lemmatize(w,"v"))

print("Filtered Tokens After Removing Punctuations:",filtered_tokens)
print("Lemmatized Tokens:",lemmetized_words)
# Out:
# Filtered Tokens After Removing Punctuations: ['sri', 'lanka', 'defeated', 'pakistan', '23', 'runs', 'summit', 'clash', 'asia', 'cup', '2022', 'sunday', 'dubai', 'international', 'stadium', 'unbeaten', 'knock', '71', 'runs', 'bhanuka', 'rajapaksa', 'four-wicket', 'haul', 'pramod', 'madushan', 'helped', 'sri', 'lanka', 'clinch', 'sixth', 'asia', 'cup', 'title', 'team', 'garnering', 'praise', 'world', 'spectacular', 'performance', 'tournament', 'following', 'win', 'players', 'took', 'part', 'massive', 'victory', 'parade', 'returned', 'home', 'tuesday', 'morning', 'players', 'welcomed', 'officials', 'sri', 'lanka', 'cricket', 'sports', 'ministry', 'bandaranaike', 'international', 'airport', 'pictures', 'posted', 'sri', 'lanka', 'cricket', 'twitter', 'players', 'seen', 'travelling', 'double-decker', 'bus', 'fans', 'roadside', 'cheering', 'congratulating', 'players', 'also', 'interacted', 'fans', 'thanked', 'massive', 'support', 'even', 'time', 'crisis', 'country', 'men']
# Lemmatized Tokens: ['sri', 'lanka', 'defeat', 'pakistan', '23', 'run', 'summit', 'clash', 'asia', 'cup', '2022', 'sunday', 'dubai', 'international', 'stadium', 'unbeaten', 'knock', '71', 'run', 'bhanuka', 'rajapaksa', 'four-wicket', 'haul', 'pramod', 'madushan', 'help', 'sri', 'lanka', 'clinch', 'sixth', 'asia', 'cup', 'title', 'team', 'garner', 'praise', 'world', 'spectacular', 'performance', 'tournament', 'follow', 'win', 'players', 'take', 'part', 'massive', 'victory', 'parade', 'return', 'home', 'tuesday', 'morning', 'players', 'welcome', 'officials', 'sri', 'lanka', 'cricket', 'sport', 'ministry', 'bandaranaike', 'international', 'airport', 'picture', 'post', 'sri', 'lanka', 'cricket', 'twitter', 'players', 'see', 'travel', 'double-decker', 'bus', 'fan', 'roadside', 'cheer', 'congratulate', 'players', 'also', 'interact', 'fan', 'thank', 'massive', 'support', 'even', 'time', 'crisis', 'country', 'men']

# %% [markdown]
# ## PoS Tagging

# %%
text = """Sri Lanka defeated Pakistan by 23 runs in the summit clash of Asia Cup 2022, on Sunday at Dubai International Stadium. The unbeaten knock of 71 runs by Bhanuka Rajapaksa and a four-wicket haul by Pramod Madushan, helped Sri Lanka clinch their sixth Asia Cup title. The team has been garnering praise from all over the world for their spectacular performance in the tournament and following their win, the players took part in a massive victory parade, when they returned home on Tuesday morning. The players were welcomed by officials from Sri Lanka Cricket and the Sports Ministry at the Bandaranaike International Airport.

In the pictures posted by Sri Lanka Cricket on their Twitter, the players were seen travelling in a double-decker bus, with fans on the roadside cheering and congratulating them. The players also interacted with the fans and thanked them for their massive support, even during the time of crisis in the country.

men's
"""

tokens = word_tokenize(text)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/avinash/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from nltk import pos_tag

pos_tag(tokens)
# Out:
# [('Sri', 'NNP'),
#  ('Lanka', 'NNP'),
#  ('defeated', 'VBD'),
#  ('Pakistan', 'NNP'),
#  ('by', 'IN'),
#  ('23', 'CD'),
#  ('runs', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('summit', 'NN'),
#  ('clash', 'NN'),
#  ('of', 'IN'),
#  ('Asia', 'NNP'),
#  ('Cup', 'NNP'),
#  ('2022', 'CD'),
#  (',', ','),
#  ('on', 'IN'),
#  ('Sunday', 'NNP'),
#  ('at', 'IN'),
#  ('Dubai', 'NNP'),
#  ('International', 'NNP'),
#  ('Stadium', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('unbeaten', 'JJ'),
#  ('knock', 'NN'),
#  ('of', 'IN'),
#  ('71', 'CD'),
#  ('runs', 'NNS'),
#  ('by', 'IN'),
#  ('Bhanuka', 'NNP'),
#  ('Rajapaksa', 'NNP'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('four-wicket', 'NN'),
#  ('haul', 'NN'),
#  ('by', 'IN'),
#  ('Pramod', 'NNP'),
#  ('Madushan', 'NNP'),
#  (',', ','),
#  ('helped', 'VBD'),
#  ('Sri', 'NNP'),
#  ('Lanka', 'NNP'),
#  ('clinch', 'VBP'),
#  ('their', 'PRP$'),
#  ('sixth', 'JJ'),
#  ('Asia', 'NNP'),
#  ('Cup', 'NNP'),
#  ('title', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('team', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('garnering', 'VBG'),
#  ('praise', 'NN'),
#  ('from', 'IN'),
#  ('all', 'DT'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('for', 'IN'),
#  ('their', 'PRP$'),
#  ('spectacular', 'JJ'),
#  ('performance', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('tournament', 'NN'),
#  ('and', 'CC'),
#  ('following', 'VBG'),
#  ('their', 'PRP$'),
#  ('win', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('players', 'NNS'),
#  ('took', 'VBD'),
#  ('part', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('massive', 'JJ'),
#  ('victory', 'NN'),
#  ('parade', 'NN'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('they', 'PRP'),
#  ('returned', 'VBD'),
#  ('home', 'NN'),
#  ('on', 'IN'),
#  ('Tuesday', 'NNP'),
#  ('morning', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('players', 'NNS'),
#  ('were', 'VBD'),
#  ('welcomed', 'VBN'),
#  ('by', 'IN'),
#  ('officials', 'NNS'),
#  ('from', 'IN'),
#  ('Sri', 'NNP'),
#  ('Lanka', 'NNP'),
#  ('Cricket', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Sports', 'NNP'),
#  ('Ministry', 'NNP'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Bandaranaike', 'NNP'),
#  ('International', 'NNP'),
#  ('Airport', 'NNP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('pictures', 'NNS'),
#  ('posted', 'VBN'),
#  ('by', 'IN'),
#  ('Sri', 'NNP'),
#  ('Lanka', 'NNP'),
#  ('Cricket', 'NNP'),
#  ('on', 'IN'),
#  ('their', 'PRP$'),
#  ('Twitter', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('players', 'NNS'),
#  ('were', 'VBD'),
#  ('seen', 'VBN'),
#  ('travelling', 'VBG'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('double-decker', 'NN'),
#  ('bus', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('fans', 'NNS'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('roadside', 'NN'),
#  ('cheering', 'NN'),
#  ('and', 'CC'),
#  ('congratulating', 'VBG'),
#  ('them', 'PRP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('players', 'NNS'),
#  ('also', 'RB'),
#  ('interacted', 'VBN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('fans', 'NNS'),
#  ('and', 'CC'),
#  ('thanked', 'VBD'),
#  ('them', 'PRP'),
#  ('for', 'IN'),
#  ('their', 'PRP$'),
#  ('massive', 'JJ'),
#  ('support', 'NN'),
#  (',', ','),
#  ('even', 'RB'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('of', 'IN'),
#  ('crisis', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('.', '.'),
#  ('men', 'NNS'),
#  ("'s", 'POS')]

# %% [markdown]
# ## NER

# %%
import nltk
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/avinash/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /home/avinash/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
sent="New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases."

nltk.pos_tag(word_tokenize(sent))
# Out:
# [('New', 'NNP'),
#  ('York', 'NNP'),
#  ('City', 'NNP'),
#  ('on', 'IN'),
#  ('Tuesday', 'NNP'),
#  ('declared', 'VBD'),
#  ('a', 'DT'),
#  ('public', 'JJ'),
#  ('health', 'NN'),
#  ('emergency', 'NN'),
#  ('and', 'CC'),
#  ('ordered', 'VBD'),
#  ('mandatory', 'JJ'),
#  ('measles', 'NNS'),
#  ('vaccinations', 'NNS'),
#  ('amid', 'IN'),
#  ('an', 'DT'),
#  ('outbreak', 'NN'),
#  (',', ','),
#  ('becoming', 'VBG'),
#  ('the', 'DT'),
#  ('latest', 'JJS'),
#  ('national', 'JJ'),
#  ('flash', 'NN'),
#  ('point', 'NN'),
#  ('over', 'IN'),
#  ('refusals', 'NNS'),
#  ('to', 'TO'),
#  ('inoculate', 'VB'),
#  ('against', 'IN'),
#  ('dangerous', 'JJ'),
#  ('diseases', 'NNS'),
#  ('.', '.')]

# %%
from nltk import ne_chunk

sent="New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases."

for chunk in ne_chunk(nltk.pos_tag(word_tokenize(sent))):
        if hasattr(chunk, 'label'):
            print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# GPE New York City

# %% [markdown]
# ## Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
def word_cloud(title_, text):
    """ Create WorldCloud """
    stopword_list = set(STOPWORDS) 

    wordcloud = WordCloud(width = 400, height = 200, 
                    background_color ='blue', 
                    stopwords = stopword_list, 
                    min_font_size = 10).generate(text) 

    # plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.title(title_, fontsize=20)
    plt.show()

# %%
word_cloud("Asia Cup", text)
